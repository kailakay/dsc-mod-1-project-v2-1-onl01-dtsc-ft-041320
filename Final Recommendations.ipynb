# %%
import seaborn as sns
import functions as fun
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %% [markdown]
# # Recommendations

# %% [markdown]
# # Final Top 5 Genres

# %% [markdown]
# ### Domestic

# %% [markdown]
# Utilizing the information Leighanna found in Genre Popularity and comparing that to the top grossing genres, we came up with a list of our Top 5 performing genres. Items that showed up in the top 7 of most popular and highest grossing were given priority. After that, we viewed the popularity graphs versus the gross and ROI to determine an ease of popularity. This measure was determined by the shape of the violin, whether the displacement of ROI was squat, indicating a 'hit or miss' type scenario or if it was long and held a high average.
#
# Our final Top 5 Performing Genres (in no particular order) is as follows:

# %% [markdown]
# ##### Action, Adventure, Animation, Drama, & Musical

# %%
# %store -r GenrePopMaster

# %%
GenrePopMaster.head()
# Out:
#    index         Title   Genre  Domestic Gross  Foreign Gross  \
# 0      0           '71  Action       1300000.0       355000.0
# 1      1     12 Rounds  Action      12234694.0      5071954.0
# 2      2     12 Strong  Action      45800000.0     21600000.0
# 3      3  13 Assassins  Action        803000.0     16800000.0
# 4      4     14 Blades  Action             0.0      3800000.0
#
#    Worldwide Gross  Production Budget  Return Rate Worldwide  \
# 0        1655000.0                0.0               0.000000
# 1       17306648.0         20000000.0              86.533240
# 2       71118378.0         35000000.0             203.195366
# 3       17603000.0                0.0               0.000000
# 4        3800000.0                0.0               0.000000
#
#    Return Rate Domestic
# 0              0.000000
# 1             61.173470
# 2            130.857143
# 3              0.000000
# 4              0.000000

# %%
g = sns.catplot(x= 'Genre', y= 'Return Rate Domestic', kind='violin', data = GenrePopMaster, palette =(sns.color_palette("rocket_r")))
g.fig.suptitle('Rate of Return by Genre: Top 5 Genres')
g.fig.set_figwidth(18)
g.fig.set_figheight(10)

# %% [markdown]
# # Actionable Insights
